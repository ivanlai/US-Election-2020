# %%
import os
import sys
import re
import json
import time
import emoji
import random
import numpy as np
import pandas as pd
from pandarallel import pandarallel
from copy import deepcopy
from datetime import date, datetime
from collections import Counter, OrderedDict

from IPython.display import clear_output

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
# t0 = time.time()

# %%
cfg = dict()
cfg['input dir']   = 'input'
cfg['sample_size'] = 10000

# %%
inFile = os.path.join(cfg['input dir'], 'Tweets_US.csv')
tweets_df = pd.read_csv(inFile, lineterminator='\n')

columns_to_drop = ['user_verified', 'truncated', 'is_retweet', 'coordinates', 'has_media_type', 
                   'in_reply_to_status_id', 'source']
tweets_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
tweets_df['date'] = tweets_df['timestamp'].apply(lambda x: x[:x.find(' ')])

print(f'Number of tweets: {len(tweets_df) :,}')
# Out:
# Number of tweets: 645,253

# %%
tweets_df.head(2)
# Out:
#                     id    user_name          user_location  \
# 0  1323052187539353600  Julie Frein  Headingley, Leeds, UK
# 1  1323052185270235136  Bev 🏃‍♀️     Canada
#
#                                                                                                                                           user_description  \
# 0  BA(Hons) Art Vis Comm. Expat American living in UK, Divorced, walking a positive path. PLEASE, no DMS if only wanting a 'date'. #Resistance #lovepeople
# 1  🇨🇦 🍁 Outdoor & animal enthusiast! Love my family my dog & Passion Fruit tea! #cdnpoli #onpoli #blacklivesmatter #humanrights #lgbtq 🏳️‍🌈
#
#           user_created  user_followers  user_friends  user_favourites  \
# 0  2009-02-19 02:14:14  1222            1282          17866
# 1  2012-10-20 15:40:25  3232            4991          64742
#
#              timestamp  \
# 0  2020-11-01 23:59:57
# 1  2020-11-01 23:59:56
#
#                                                                                                                                                                                                                                                                                                         text  \
# 0  @realDonaldTrump Dumpy Donnie is the candidate of rioters, looters, arsonists, gun-toting Billy-Bubbas, terrorists, lobbyists and special interests. Biden is the candidate of farmers, factory workers, police officers, and hard-working, law-abiding patriots of every race, religion and creed #BIDEN
# 1  The Time has Come! #VOTE #Election2020 #RaiseYourVoice #BLM #BidenHarris2020ToSaveAmerica #coronavirus #VoteBlueToEndTheNightmare #Trump #RepublicansForBiden https://t.co/H0YpFeNBtG
#
#                                                                                                                                                         hashtags  \
# 0  ['BIDEN']
# 1  ['VOTE', 'Election2020', 'RaiseYourVoice', 'BLM', 'BidenHarris2020ToSaveAmerica', 'coronavirus', 'VoteBlueToEndTheNightmare', 'Trump', 'RepublicansForBiden']
#
#    retweet_count  favorite_count        date
# 0  0              0               2020-11-01
# 1  0              0               2020-11-01

# %% [markdown]
# #### Location

# %%
places_df = pd.read_csv(os.path.join(cfg['input dir'], 'City_Country.csv'))
places_df = places_df.applymap(lambda x: str(x).lower())

# %%
countries = set(places_df.country.unique())
print(f"countries has {len(countries) :,} entries")
# Out:
# countries has 244 entries

# %%
city_to_subcountry = places_df[['city','subcountry']].set_index('city').T.to_dict('records')
city_to_subcountry = city_to_subcountry[0]
# Out:
# /home/ivan/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.

# %%
city_to_country = places_df[['city','country']].set_index('city').T.to_dict('records')
city_to_country = city_to_country[0]

#Append special cases:
additonals = {
    'uk' : 'united kingdom',
    'us' : 'united states',
    'usa': 'united states',
    '美國': 'united states',
    '香港': 'hong kong',
    '日本': 'japan',
    '東京': 'japan',
    '台灣': 'taiwan',
    '台北': 'taiwan',
    '北京': 'china',
    '上海': 'china',
    '中华人民共和国': 'china'
}

city_to_country.update(additonals)
print(f"city_to_country has {len(city_to_country) :,} entries")
# Out:
# /home/ivan/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.
# city_to_country has 21,952 entries

# %%
subcountry_to_country = places_df[['subcountry', 'country']].set_index('subcountry').T.to_dict('records')
subcountry_to_country = subcountry_to_country[0]
print(f"subcountry_to_country has {len(subcountry_to_country) :,} entries")
# Out:
# /home/ivan/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   """Entry point for launching an IPython kernel.
# subcountry_to_country has 2,592 entries

# %%
def find_countries(text):        
    
    if not isinstance(text, str):
        return np.nan
    
    #------------------------------------#
    def lookup(term):        
        if term in countries:
            return term
        elif term in city_to_country:            
            return city_to_country[term]
        elif term in subcountry_to_country:
            return subcountry_to_country[term]
        else:
            return ''
    #------------------------------------#
    
    Y = set()
    terms = text.split()
        
    if len(text) == 0:
        return Y
    
    elif len(terms) == 1:
        result = lookup(terms[0])
        if len(result) > 0:
            Y.add(result)                          
    else:   
        check_single_term = True  
        
        for t1, t2 in zip(terms[:-1], terms[1:]):                      
            result = lookup(f'{t1} {t2}')            
            if len(result) > 0:
                Y.add(result)
                check_single_term = False        
                
            elif check_single_term:
                result = lookup(t1)
                if len(result) > 0:
                    Y.add(result)                    
            else:
                check_single_term = True
          
        if check_single_term:
            result = lookup(terms[-1])
            if len(result) > 0:
                Y.add(result)    

    return Y

# %%
def clean(text):
    if isinstance(text, str):
        text = emoji.demojize(text)    
        text = re.sub(r'([^\w]|\_)', ' ', text) 
        return " ".join(text.lower().split())
    else:
        return text

# %%
# %%time
pandarallel.initialize()

#--------------------------------------------#
tweets_df['user_location'] = tweets_df['user_location'].parallel_apply(lambda x: clean(x))
tweets_df['countries'] = tweets_df['user_location'].parallel_apply(lambda x: find_countries(x))
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# CPU times: user 1.91 s, sys: 1.31 s, total: 3.22 s
# Wall time: 12.2 s

# %% [markdown]
# #### Find States within US

# %%
states_df = pd.read_csv(os.path.join(cfg['input dir'], 'USA_States_code.csv'))

states = set(state.lower() for state in states_df.State.values)

code_lookup, abbrev_lookup = dict(), dict()
for state, abbrev, code in states_df.values:
    code_lookup[code.lower()] = state.lower()
    abbrev_lookup[abbrev.lower()] = state.lower()

# %%
# %%time

def get_us_states(df):
    
    #----------------------------------------------#
    def lookup(term):
        if term in states:
            return term
        elif term in code_lookup:
            return code_lookup[term]
        elif term in abbrev_lookup:
            return abbrev_lookup[token]      
        return ''
    #----------------------------------------------#
    
    us_states = []
    for location, countries in df[['user_location', 'countries']].values:           

        Y = set()
        if pd.notnull(countries) and 'united states' in countries:
            tokens = location.lower().split()

            if len(tokens) == 1:
                result = lookup(tokens[0])
                if len(result) > 0:
                    Y.add(result)  

            else:   
                check_single_term = True 

                for t1, t2 in zip(tokens[:-1], tokens[1:]):                      
                    result = lookup(f'{t1} {t2}')            
                    if len(result) > 0:
                        Y.add(result)
                        check_single_term = False        

                    elif check_single_term:
                        result = lookup(t1)
                        if len(result) > 0:
                            Y.add(result)
                    else:
                        check_single_term = True

                if check_single_term:
                    result = lookup(tokens[-1])
                    if len(result) > 0:
                        Y.add(result)  
                        
        if len(Y) == 0:
            Y.add('usa')

        if 'washington' in Y and 'district of columbia' in Y:
            Y.remove('washington')
            
        us_states.append(list(Y))

    return us_states
#----------------------------------------------#

tweets_df['states'] = get_us_states(tweets_df)
# Out:
# CPU times: user 5.94 s, sys: 161 ms, total: 6.1 s
# Wall time: 6.1 s

# %% [markdown]
# #### Test data set (include training and validation)

# %%
export_columns = ['id', 'user_name', 'user_description', 'text', 'states', 'date']

# %%
ids = []
for id_, state in tweets_df[['id', 'states']].values:
    if len(state) > 0:
        ids.append(id_)

ids = set(ids)
test_df = tweets_df[tweets_df.id.isin(ids)]

test_df['user_created datetime'] = test_df['user_created'].apply(lambda s: datetime.fromisoformat(s))
test_df = test_df[test_df['user_created datetime'] < datetime.fromisoformat('2020-09-01')]

print(f"test_df: {test_df.shape}")
test_df[export_columns].to_csv('test', index=False)
# Out:
# test_df: (621338, 17)

# %%
test_df.head(1)
# Out:
#                     id    user_name        user_location  \
# 0  1323052187539353600  Julie Frein  headingley leeds uk
#
#                                                                                                                                           user_description  \
# 0  BA(Hons) Art Vis Comm. Expat American living in UK, Divorced, walking a positive path. PLEASE, no DMS if only wanting a 'date'. #Resistance #lovepeople
#
#           user_created  user_followers  user_friends  user_favourites  \
# 0  2009-02-19 02:14:14  1222            1282          17866
#
#              timestamp  \
# 0  2020-11-01 23:59:57
#
#                                                                                                                                                                                                                                                                                                         text  \
# 0  @realDonaldTrump Dumpy Donnie is the candidate of rioters, looters, arsonists, gun-toting Billy-Bubbas, terrorists, lobbyists and special interests. Biden is the candidate of farmers, factory workers, police officers, and hard-working, law-abiding patriots of every race, religion and creed #BIDEN
#
#     hashtags  retweet_count  favorite_count        date         countries  \
# 0  ['BIDEN']  0              0               2020-11-01  {united kingdom}
#
#   states user_created datetime
# 0  [usa] 2009-02-19 02:14:14

# %% [markdown]
# #### Get sample for training

# %% [markdown]
# We assume certain hashtags in text reflect voting intention. This is not always correct, but spot checking samples of a few hundred suggests they are about 90% correct.

# %%
for_Trump_hashtags = ['trump2020landslide', 'trump2020landslidevictory', 'trump2020tosaveamerica', 
                      'bidencrimefamily']

for_Biden_hashtags = ['trumpcovid', 'trumpvirus', 'votehimout', 'voteblue', 'trumpisanationaldisgrace', 
                      'trumpmeltdown', 'trumpcrimefamily']

# %%
# %%time

trump_ht = set(for_Trump_hashtags)
biden_ht = set(for_Biden_hashtags)

Y = []
c = 0
for hashtags in tweets_df.hashtags.values:    
    hashtags = [h.lower() for h in eval(hashtags)]
        
    biden, trump = False, False
    tmp = 'neutral'
    
    if len(set(hashtags).intersection(trump_ht)) > 0:
        tmp = 'trump'
        trump = True
        
    if len(set(hashtags).intersection(biden_ht)) > 0:
        tmp = 'biden'
        biden = True
    
    if biden and trump:
        tmp = 'neutral'
        c += 1 #count of both
        
    Y.append(tmp)

#--------------------------------#
tweets_df['support'] = Y


#--------------------------------#
print(f"All: {len(tweets_df) :,}")
print(f"Neither: {len(tweets_df[tweets_df['support']=='neutral']) :,}")
print(f"Trump: {len(tweets_df[tweets_df['support']=='trump']) :,}")
print(f"Biden: {len(tweets_df[tweets_df['support']=='biden']) :,}")
print(f"Both: {c :,}")
# Out:
# All: 645,253
# Neither: 593,515
# Trump: 9,223
# Biden: 42,515
# Both: 557
# CPU times: user 10.5 s, sys: 71 ms, total: 10.6 s
# Wall time: 10.6 s

# %%
sample = dict()
for candidate in ['trump', 'biden']:
    ind = tweets_df[tweets_df.support==candidate].index
    
    sample_size = min(len(ind), cfg['sample_size'])
    ind = random.sample(list(ind), sample_size)
    sample[candidate] = tweets_df[tweets_df.index.isin(ind)]
    sample[candidate].loc[:, 'support'] = candidate
    
# sample = dict()
# for candidate in ['trump', 'biden']:
#     sample[candidate] = tweets_df[tweets_df.support==candidate]
#     sample[candidate].loc[:, 'support'] = candidate
# Out:
# /home/ivan/anaconda3/envs/ML/lib/python3.7/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
users_df = sample['trump'][['user_name', 'id']].groupby(['user_name']).count()
len(users_df)
# Out:
# 5029

# %%
users_df = sample['biden'][['user_name', 'id']].groupby(['user_name']).count()
len(users_df)
# Out:
# 5416

# %%
sample['trump'][['user_name', 'user_location', 'user_created', 'text', 'hashtags', 'support']].head(20)
# Out:
#                                             user_name  \
# 8    Marios Gooner
# 83   Clark
# 93   kstev99
# 104  RoqnRobn
# 132  ً
# 163  Broad Street Sports
# 187  Rebecca Axsom
# 231  Belaaz Fan
# 269  Belaaz Fan
# 271  ⁴MR. RUPERT MARCELLE HUCKS📖Iam I am I am📲&Ūr²;✈)
# 292  Mike Jones
# 352  🌻Robin🌻
# 358  ci_pi_ku
# 359  Keith Stoneberger
# 360  Lynnzy T.
# 368  James
# 418  🇺🇸Deplorable Hillbilly❌
# 461  Philip Calrissian
# 529  JimMason
# 641  SurvivalJane
#
#                   user_location         user_created  \
# 8    london england              2009-12-15 09:23:17
# 83   NaN                         2017-04-04 20:16:18
# 93   atwood il                   2016-08-23 17:35:24
# 104  NaN                         2013-04-24 00:41:56
# 132  cowboy hat face             2018-07-24 06:56:44
# 163  philadelphia pa             2017-01-17 17:05:56
# 187  NaN                         2012-04-12 18:26:27
# 231  NaN                         2019-12-08 07:21:07
# 269  NaN                         2019-12-08 07:21:07
# 271  port vue pa                 2012-11-30 05:06:40
# 292  NaN                         2020-10-09 19:24:36
# 352  indian rocks beach fl       2011-05-12 13:14:20
# 358  u r anus                    2020-10-21 07:45:52
# 359  shenandoah va               2009-03-15 00:55:32
# 360  buffalo ny                  2009-03-01 02:18:24
# 368  37 13 57 2 n 115 48 56 9 w  2020-04-04 16:01:35
# 418  NaN                         2011-12-05 17:59:05
# 461  london uk                   2013-11-14 00:45:46
# 368  #Trump #Trump2020Landslide \n\nJourney - Don't Stop Believin'\nhttps://t.co/CWdpGJPIpw
# 418  This is what every Democrat thinks of you and I. Let’s show them what “Chumps” are at the voting booth. #TRUMP2020ToSaveAmerica #VoteRedLikeYourLifeDependsOnIt #VoteRedDownBallot #VoteRepublican #KAG #MAGA #VOTE 🇺🇸#TakeBackTheHouse #Trump #WalkAway https://t.co/SkYY5vCtPe
# 461  Rally 3 of 5, Hickory, NC\nLIVE: https://t.co/OnLIhey7xP\n#Trump2020Landslide #Trump https://t.co/1VunjZP1H6
# 529  Watch: Caravan Of Vehicles For #Trump Shut Down New Jersey Highway \n\nhttps://t.co/7To1cN1xVU #TRUMP2020ToSaveAmerica #Trump2020DCBeltway #Trump2020Landslide #JoeBidenIsSick #JoeBiden #walkaway #Trump2020LandslideVictory
# 641  @realDonaldTrump @DanScavino @GOPLeader @GOPChairwoman @JudicialWatch @JudicialWatch @TrumpWarRoom @WarRoomPandemic @QUEENSNY @SMHAllDayLong \nWhat is being done about this??? #Trump will win in a #Trump2020Landslide ,but this kind of nonsense needs to be addressed pronto! https://t.co/5MEcGNlcE8
#
#                                                                                                                                                                                    hashtags  \
# 8    ['Trump', 'Trump2020Landslide', 'MAGA2020']
# 83   ['TRUMP2020ToSaveAmerica', 'Trump', 'Trump2020']
# 93   ['WalkAway', 'DemsAreDestroyingAmerica', 'BidenHarris2020', 'Trump2020Landslide', 'VoteRedToSaveAmerica', 'Corruption', 'BLEXIT', 'Trump']
# 104  ['Biden', 'JoeBiden', 'JOEBIDEN2020', 'KamalaHarris', 'ElectJustice', 'ElectionDay', 'Elections2020', 'Trump2020', 'Trump2020LandslideVictory', 'TrumpLandslide2020', 'VoteTrump2020']
# 132  ['TRUMP2020', 'Trump2020Landslide', 'TrumpTraintexas', 'TrumpPence2020', 'trump']
# 163  ['TrumpParade', 'Trump2020Landslide', 'VOTE', 'VoteRepublican', 'KeepAmericaGreat', 'Trump']
# 187  ['Trump', 'Trump', 'ElectionDay', 'TRUMP2020ToSaveAmerica', 'Trump2020', 'GREATESTPRESIDENTEVER45', 'MAGA']
# 231  ['Trump', 'Trump2020', 'Trump2020Landslide']
# 269  ['JewsForTrump', 'Trump', 'Trump2020', 'Trump2020Landslide']
# 271  ['Trump', 'Hickory', 'NorthCarolina', 'Trump2020Landslide']
# 292  ['Trump', 'Trump2020Landslide', 'TrumpTrain', 'BidenCrimeFamiIy', 'TrumpIsCompromised']
# 352  ['trump', 'Trump2020Landslide', 'VoteRedToSaveAmerica2020']
# 358  ['Trump', 'ElectionDay', 'Biden', 'Election2020', 'BarackObama', 'Trump2020Landslide']
# 359  ['Biden', 'BidenCrimeFamiIy', 'KamalaHarrisVP', 'Trump2020Landslide', 'MAGA2020']
# 360  ['IVoted', 'Trump', 'Trump2020Landslide', 'TrumpLandslide2020', 'TrumpLandslide', 'TrumpLandslideVictory2020']
# 368  ['Trump', 'Trump2020Landslide']
# 418  ['TRUMP2020ToSaveAmerica', 'VoteRedLikeYourLifeDependsOnIt', 'VoteRedDownBallot', 'VoteRepublican', 'KAG', 'MAGA', 'VOTE', 'TakeBackTheHouse', 'Trump', 'WalkAway']
# 461  ['Trump2020Landslide', 'Trump']
# 529  ['Trump', 'TRUMP2020ToSaveAmerica', 'Trump2020DCBeltway', 'Trump2020Landslide', 'JoeBidenIsSick', 'JoeBiden', 'walkaway', 'Trump2020LandslideVictory']
# 641  ['Trump', 'Trump2020Landslide']
#
#     support
# 8    trump
# 83   trump
# 93   trump
# 104  trump
# 132  trump
# 163  trump
# 187  trump
# 231  trump
# 269  trump
# 271  trump
# 292  trump
# 352  trump
# 358  trump
# 359  trump
# 360  trump
# 368  trump
# 418  trump
# 461  trump
# 529  trump
# 641  trump

# %%
sample['biden'][['user_name', 'user_location', 'user_created', 'text', 'hashtags', 'support']].head(20)
# Out:
#                                user_name                user_location  \
# 87    archygirl                           NaN
# 133   archygirl                           NaN
# 239   gillian simpson                     NaN
# 287   Gary McMurray                       planet earth
# 544   #Biden🗣️NoMalarkey                  california usa
# 562   The Ubiquitous J-Man                toronto canada
# 575   David Harpin                        new haven connecticut
# 661   Rocky Vendetti                      NaN
# 686   Valerie Martin                      las vegas nv bwo detroit mi
# 823   Chris                               england
# 851   Markus Leads                        owl
# 889   TrumpsBrain                         washington dc
# 1053  Pretty Jimmy | BLM                  strong island new yawwkk
# 1109  SaanichGuy 🇨🇦🌊🌊❄️                   saanich bc canada
# 1221  Nairn L McDonald FRSA - #WearAMask  personal account views
# 1468  Barefoot_Positivity                 california
# 1496  Michael🌊🌊🌊 #BIDENHARRIS2020         backup to mterr337
# 1555  Cisco Ramos 🇵🇷 🏳️‍🌈                 the bronx ny
# 1632  Tony Cronin 🇨🇦🏳️‍🌈🧢                 edmonton
# 1761  Nomad!                              california usa
#
#              user_created  \
# 87    2020-01-05 04:53:07
# 133   2020-01-05 04:53:07
# 239   2013-12-13 14:47:56
# 287   2016-07-17 08:25:05
# 544   2016-05-28 05:44:54
# 562   2009-05-24 10:52:00
# 575   2013-06-27 09:19:02
# 661   2020-09-15 18:37:41
# 686   2011-01-19 02:58:29
# 823   2016-12-19 13:52:49
# 851   2013-03-18 19:55:28
# 889   2018-06-12 07:19:03
# 1053  2011-07-18 22:40:42
# 1109  2011-10-15 20:41:40
# 1221  2009-04-17 17:28:09
# 1468  2009-02-17 01:19:41
# 1496  2020-09-07 18:45:02
# 1555  2017-02-08 17:03:07
# 1632  2009-03-08 18:15:20
# 1761  2015-11-19 19:31:22
#
#                                                                                                                                                                                                                                                                                                                                        text  \
# 87    Thank you Lincoln Project. America Deserves Better. #LincolnProject #SenateBlueWave #TrumpHasNoPlan #Biden #BidenHarris #BlueWave #BidenHarris2020ToSaveAmerica #ObamaWasBetterAtEverything #TrumpDeathToll236K #TrumpCrimesAgainstHumanity #VoteBlue #NastyWoman https://t.co/vFNcg3meeM
# 1221  Watching #Trump supporters blocking roads, bridges and attempting to force the Biden Bus off the road makes clear that they are the real threat to USA and its democracy.\n\nTheir actions are nothing short of domestic terrorism.\n\n#Biden\n#TrumpIsLosing\n#VoteBlue\n#JoeBiden
# 1468  Handsome!!  #VoteBiden #Biden #BidenHarris #VoteBlue #VoteBlueToSaveAmerica https://t.co/DHj0vvS3SR
# 1496  #trump has been losing in the courts over trying to suppress the vote...but most importantly he's losing on election day!\n\n#BuildBackBetter \n#BidenHarrisWillLead\n#BidenHarris \n#VoteBlue #VOTE
# 1555  @ladygaga #IVoted #IVotedEarly #Biden #BidenHarris #VOTE #VoteHimOut #VoteEarly as a proud Puerto Rican, a proud gay man, and a proud New Yorker I stand with #JoeBiden and #KamalaHarris 🇵🇷🏳️‍🌈🗽 https://t.co/6xZEDY1Hxg
# 1632  @GOP @realDonaldTrump If Trump wins, Russia wins, no just kidding,  NOBODY ( other than Trump ) wins.\n#Biden  #2020Election #Biden2020 #TrumpMeltdown
# 1761  @realDonaldTrump GOOD PEOPLE ON BOTH SIDE!?  Do you think that #Trump lies so damn much, he can't keep track of his own Lie's?? #coronavirus #Covidiotas #TrumpMeltdown #TrumpLandslideVictory2020 #SundayLive @JoeNBC @ProjectLincoln @steelworkers @SteveSchmidtSES @JoeBiden @BarackObama @morningmika https://t.co/CQ4Ihq1Rxv
#
#                                                                                                                                                                                                                                     hashtags  \
# 87    ['LincolnProject', 'SenateBlueWave', 'TrumpHasNoPlan', 'Biden', 'BidenHarris', 'BlueWave', 'BidenHarris2020ToSaveAmerica', 'ObamaWasBetterAtEverything', 'TrumpDeathToll236K', 'TrumpCrimesAgainstHumanity', 'VoteBlue', 'NastyWoman']
# 133   ['SenateBlueWave', 'TrumpHasNoPlan', 'Biden', 'BidenHarris', 'BlueWave', 'BidenHarris2020ToSaveAmerica', 'ObamaWasBetterAtEverything', 'TrumpDeathToll236K', 'TrumpCrimesAgainstHumanity', 'VoteBlue', 'NastyWoman']
# 239   ['Biden', 'Trump', 'ElectoralCollege', 'vote', 'voteblue']
# 287   ['Trump', 'TrumpCrimeFamily', 'Trump2020', 'TrumpTrain', 'USA']
# 544   ['Trump', 'healthcare', 'healthcareworkers', 'VoteHimOut', 'coronavirus', 'AmericaOrTrump', 'RepublicansAgainstTrump']
# 562   ['USPoli', 'Trump', 'TrumpIsANationalDisgrace', 'TrumpIsUnwell', 'TrumpIsLosing', 'TrumpIsALoser', 'TrumpIsPathetic', 'EnoughIsEnough']
# 575   ['Election2020', 'TrumpMeltdown', 'Trump', 'nihilism', 'AmericaOrTrump', 'AmericasGreatestMistake']
# 661   ['VoteBlue', 'VoteBlueToSaveAmerica', 'Biden', 'BidenHarris2020ToSaveAmerica']
# 686   ['DonaldTrump', 'TrumpCrimeFamily', 'Biden', 'LockThemUp', 'VoteBlue']
# 823   ['Trump', 'TrumpMeltdown']
# 851   ['trump', 'AmericanIdiot', 'VoteHimOut']
# 889   ['Illinois', 'Illinoisans', 'Coronavirus', 'Trump', 'TrumpIsANationalDisgrace']
# 1053  ['MAGA', 'Biden', 'TrumpIsANationalDisgrace']
# 1109  ['trump', 'BidenHarris', 'TrumpCrimeFamily']
# 1221  ['Trump', 'Biden', 'TrumpIsLosing', 'VoteBlue', 'JoeBiden']
# 1468  ['VoteBiden', 'Biden', 'BidenHarris', 'VoteBlue', 'VoteBlueToSaveAmerica']
# 1496  ['trump', 'BuildBackBetter', 'BidenHarrisWillLead', 'BidenHarris', 'VoteBlue', 'VOTE']
# 1555  ['IVoted', 'IVotedEarly', 'Biden', 'BidenHarris', 'VOTE', 'VoteHimOut', 'VoteEarly', 'JoeBiden', 'KamalaHarris']
# 1632  ['Biden', '2020Election', 'Biden2020', 'TrumpMeltdown']
# 1761  ['Trump', 'coronavirus', 'Covidiotas', 'TrumpMeltdown', 'TrumpLandslideVictory2020', 'SundayLive']
#
#      support
# 87    biden
# 133   biden
# 239   biden
# 287   biden
# 544   biden
# 562   biden
# 575   biden
# 661   biden
# 686   biden
# 823   biden
# 851   biden
# 889   biden
# 1053  biden
# 1109  biden
# 1221  biden
# 1468  biden
# 1496  biden
# 1555  biden
# 1632  biden
# 1761  biden

# %%
training_df = pd.DataFrame()
training_df = pd.concat([training_df, sample['trump']], axis=0)
training_df = pd.concat([training_df, sample['biden']], axis=0)
training_df[export_columns + ['support']].to_csv('training', index=False)

# %%
len(training_df)
# Out:
# 19223

# %% [markdown]
# #### Getting validation samples by using terms in user_name/description

# %%
for_trump = ['trump 88022', 'trump2020', 'trump 2020', 'donald trump', 'maga kag', 'trump maga', 
             'donald trump', 'text trump', 'president trump']

for_biden = ['bidenharris2020', 'dump trump', 'biden', 'vote blue', 'biden harris', 'trump bot', 
             'vote biden', 'trumpery resistance', 'joe biden', 'blue wave', 'harris 2020', '2020 blue', 
             'votebluetosaveamerica', 'vote blue', 'biden2020', 'anti trump', 'trump freakouts', 
             'water_wave water_wave']

# %%
regex = re.compile('\W')
url_regex = re.compile(r'(www|http)\S+')
        
def tokenize(text):
    if isinstance(text, str):
        text = url_regex.sub('', text) #remove link 
        text = emoji.demojize(text)
        return ' '.join([token for token in regex.split(text) if len(token)>0])
    else:
        return ''

# %%
# %%time
pandarallel.initialize()
tweets_df['user_name_tokens'] = tweets_df['user_name'].parallel_apply(lambda x: tokenize(x))
tweets_df['user_description_tokens'] = tweets_df['user_description'].parallel_apply(lambda x: tokenize(x))
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# CPU times: user 650 ms, sys: 1.44 s, total: 2.09 s
# Wall time: 1min 37s

# %%
# %%time
trump = set(for_trump)
biden = set(for_biden)

Y = []
c = 0
for name, description in zip(tweets_df.user_name_tokens.values, tweets_df.user_description_tokens.values):    
    name_description = name + ' ' + description

    biden, trump = False, False
    tmp = 'neutral'
    
    for term in for_biden:
        if name_description.find(term) >= 0:
            tmp = 'biden'
            biden = True
            break

    for term in for_trump:
        if name_description.find(term) >= 0:            
            tmp = 'trump'
            trump = True
            break
      
    if biden and trump:
        tmp = 'neutral'
        c += 1
        
    Y.append(tmp)
    
#--------------------------------#
tweets_df['support'] = Y


#--------------------------------#
print(f"All: {len(tweets_df) :,}")
print(f"Neither: {len(tweets_df[tweets_df['support']=='neutral']) :,}")
print(f"Trump: {len(tweets_df[tweets_df['support']=='trump']) :,}")
print(f"Biden: {len(tweets_df[tweets_df['support']=='biden']) :,}")
print(f"Both: {c :,}")
# Out:
# All: 645,253
# Neither: 635,618
# Trump: 774
# Biden: 8,861
# Both: 8
# CPU times: user 5.74 s, sys: 250 ms, total: 5.99 s
# Wall time: 6.02 s

# %%
trump_df = tweets_df[tweets_df['support']=='trump']
biden_df = tweets_df[tweets_df['support']=='biden']
biden_df = biden_df.groupby('user_name').head(1)

print(f"Trump: {len(trump_df) :,}")
print(f"Biden: {len(biden_df) :,}")
# Out:
# Trump: 774
# Biden: 1,648

# %%
val_df = pd.DataFrame()
val_df = pd.concat([val_df, trump_df], axis=0)
val_df = pd.concat([val_df, biden_df], axis=0)
val_df[export_columns + ['support']].to_csv('validation', index=False)

# %%
biden_df[['user_name', 'user_description', 'user_location', 'user_created', 'text', 'hashtags', 'support']].head(20)
# Out:
#                                          user_name  \
# 31    Dr. Jimmy O’Shët, PsyD 🌊🌊🌊
# 43    Blue Wave 🌊🌊🌊
# 336   ᗷᖇIᗩᑎ ᖴᒪᗩKE🌊🌊🌊
# 447   🦄⚡️💎💙☯️ Empathetic Golgi Apparatus ☯️ 💙 💎⚡️🦄
# 471   James
# 509   SoxOnTheBrain ⚾️
# 544   #Biden🗣️NoMalarkey
# 632   onlykamala_
# 687   Tbone 🌊🌊
# 754   momof4 #resist 🌊🌊🌊🌊🌊#resister #wtp2020
# 871   Sean Davis
# 886   🌊🌊SecondWaveBlueTxTrader🌊🌊
# 892   Kim Harris 🌊
# 908   ERIC JEM🌊🌊🌊🌊🌊
# 944   Darren vote blue Rigger
# 1036  Wingsfan99
# 1109  SaanichGuy 🇨🇦🌊🌊❄️
# 1143  joebiden.com/call iwillvote.com 866-OUR-VOTE
# 1245  RC💙AC #ResisterBoomers 🌊🌊 #PRU Members 🌊🌊
# 1255  Trumpinator
#
#                                                                                                                                                             user_description  \
# 31    I am a Republican against Trump! His brand of politics is counter to the core beliefs of America. I #Resist to restore decency to our country. 🌊🌊🌊 #GoJoe2020
# 43    I call out INJUSTICE where I see it 👀\nDigitalActorvist. 🔥\nI tweet A Lot because I can.\n\n#Decency #Democracy #BlueTsunami\n💙🔥🌎🌈☀🌊 🌊🌊\n#ActorVist #SAGAFTRA
# 336   #LGBT, Extremely liberal, completely unfiltered. #Bots, #MAGAts, and #Trolls blocked immediately! #BidenHarris2020 \n#FBR\n#Resist \n#Resistance\n#RidinWithBiden
# 447   #Resister #BidenHarris2020 🌊🌊 #FBR #BlackLivesMatter #ALLY🏳️‍🌈 #Skeptic #Humanist #Atheist #ThinkForYourself #CrohnsWarrior #MentalHealth #Education💙He/him
# 944   #Trump supporters are gathering in Rockland County. https://t.co/UG49Ga3IBT
# 1036  This is the nervous time.  DO NOT MAIL YOUR BALLOT, TAKE IT IN DIRECTLY.  We have been warned and we cannot be complacent.  Get off the sidelines and vote. PA,MI,Fl,NC,GA,TX,WI,AZ,MN,IA and OH. #VoteBlueToEndTheNightmare #Biden #BidenHarris #Biden2020
# 1109  @Iamme48 @86toxictrump #trump’s long list of scandals have dominated the news cycle. This one item would have been enough a decade ago? What has happened to the US &amp; @GOP \nCorruption or blackmail? If #BidenHarris wins we will find out, if not, we see the collapse of US democracy \n#TrumpCrimeFamily
# 1143  its so unfair and shitty to be sandwiched between 2 neighbors who wont shut the fuck up with their noisy video games and music--why dont you work on protecting #democracy &amp; make some damn calls at https://t.co/uc2X88QfUh ugh! #apartment #phonebanking #gotv #stfu #phonebank #biden
# 1245  @kathygriffin Someone put him in a straight-jacket he's gone mad.\n#Trump👇👇 https://t.co/E7hSK7XqOA
# 1255  Dear Dr. Atlas: \n\nInstead of focusing on epidemiology, not your specialty, please examine #Trump's X-rays, MRIs, PET and CAT scans to figure out how such a bloated load of bat guano, held together by fried chicken, hairspray, and a big red tie, still draws breath.\n#Biden\n#Trump
#
#                                                                                                                                                                                                                                                                      hashtags  \
# 31    ['trump', 'TrumpIsARacist']
# 43    ['Biden', 'BidenHarrisToSaveAmerica']
# 336   ['BlueWave', 'BlueWave2018', 'Deplorables', 'MAGA', 'MAGAts', 'putinsbitch', 'Resist', 'TheResistance', 'Trump', 'Trumpkin', 'TrumpSupporter', 'TrumpTrain2018', 'TrumpTrainPortal', 'Vote', 'VoteBlueAndBringAFriend', 'VoteBlueNov6th', 'VoteBlueToEndThisNightmare']
# 447   ['VoteBlue2020', 'BidenHarris', 'Biden', 'VOTE']
# 471   ['AmericaOrTrump', 'VoteHimOut', 'BidenHarris', 'Biden', 'TrumpMeltdown']
# 509   ['Trump', 'Biden']
# 544   ['Trump', 'healthcare', 'healthcareworkers', 'VoteHimOut', 'coronavirus', 'AmericaOrTrump', 'RepublicansAgainstTrump']
# 632   ['Trump']
# 687   ['biden']
# 754   ['trump']
# 871   ['Trump', 'brownshirt', 'thuggery', 'police', 'vigilante', 'electioneering']
# 886   ['trump']
# 892   ['Biden', 'VoteBlue']
# 908   ['Biden', 'BidenHarris']
# 944   ['Trump']
# 1036  ['VoteBlueToEndTheNightmare', 'Biden', 'BidenHarris', 'Biden2020']
# 1109  ['trump', 'BidenHarris', 'TrumpCrimeFamily']
# 1143  ['democracy', 'apartment', 'phonebanking', 'gotv', 'stfu', 'phonebank', 'biden']
# 1245  ['Trump']
# 1255  ['Trump', 'Biden', 'Trump']
#
#      support
# 31    biden
# 43    biden
# 336   biden
# 447   biden
# 471   biden
# 509   biden
# 544   biden
# 632   biden
# 687   biden
# 754   biden
# 871   biden
# 886   biden
# 892   biden
# 908   biden
# 944   biden
# 1036  biden
# 1109  biden
# 1143  biden
# 1245  biden
# 1255  biden
